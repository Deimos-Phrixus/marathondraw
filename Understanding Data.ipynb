# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os
import sys

# %%
angel_bitmaps = np.load('data/full_numpy_bitmap_angel.npy')

# %%
angel_bitmaps.shape
## Number of images x number of pixels each image
# Out:
# (149736, 784)

# %% [markdown]
# Conver bitmaps to black and white

# %%
angel_bitmaps_norm = angel_bitmaps/255 < 0.5

# %% [markdown]
# Display some of the images

# %%
w=10
h=10
fig=plt.figure(figsize=(10, 20))
columns = 10
rows = 20
for i in range(1, columns*rows +1):
    img = angel_bitmaps_norm[i].reshape((28,28))
    fig.add_subplot(rows, columns, i)
    plt.imshow(img, cmap='gray')
    plt.axis('off')
plt.show()
